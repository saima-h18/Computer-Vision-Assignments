# %% [markdown]
# ## <center> ECSE 415 - Intro to Computer Vision </center>
# ### <center> Assignment 4</center> <center> Saima Haneef - 260744058 </center>

# %%
import cv2
import matplotlib.pyplot as plt
import math
import numpy as np
import random
import os

# %% [markdown]
# ### 1

# %%
path1='./train_set/dwight/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    print(x.shape)
    p = x.flatten()
    print(p)
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))
# Out:
# (168, 138)
# [64 59 55 ... 75 65 59]
# (168, 138)
# [106 108 110 ...  88  85  84]
# (168, 138)
# [ 95  93  91 ... 109 112 112]
# (168, 138)
# [ 77  78  80 ... 132 132 132]
# (168, 138)
# [109 109 111 ...  64  65  65]
# (168, 138)
# [102 104 104 ...  90  96  97]
# (168, 138)
# [161 166 169 ...  81  77  76]
# (168, 138)
# [111 111 111 ... 168 167 167]
# (168, 138)
# [157 153 147 ... 130 130 130]
# (168, 138)
# [153 155 161 ...  98 104 105]

# %%
path1='./train_set/pam/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %%
path1='./train_set/jim/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %% [markdown]
# ### 2

# %%
path1='./train_set/dwight/'

d_mtx = np.empty((30, len(p)))
val = 0
# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
        
path2='./train_set/pam/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path2))):
    x = cv2.cvtColor(cv2.imread(path2+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1

        
path3='./train_set/jim/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path3))):
    x = cv2.cvtColor(cv2.imread(path3+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
    
print(d_mtx)
print(d_mtx.shape)




mean = np.mean(d_mtx, axis=0)
mean = mean[:, np.newaxis]
print(mean.shape)
B = np.reshape(mean, (168,138))
plt.imshow(np.real(B), cmap="gray")
plt.show()


# prod = np.dot(eigen_vectors, d_mtx)
arr1 = np.empty((30, len(p)))
print("lol")
print(d_mtx.shape)
# np.dot(eigen_vectors,d_mtx.T)
# U, Sigma, VT = np.linalg.svd(d_mtx, full_matrices=False)
# pca_vectors = np.dot(d_mtx, eigen_vectors[0]) #obtain our eigen faces
for x in range(0, len(d_mtx)):
    temp = d_mtx[x]-mean.T
    arr1[x] = temp
# x = np.copy(d_mtx)
# x = x.astype('float64')
# temp = x - np.mean(x,axis=0)
print("Arr")
print(arr1.shape)
print(arr1)

product = np.dot(arr1, arr1.T)
# product = np.cov(arr1)
product = product/arr1.shape[1]
print(product.shape)

eigen_values, eigen_vectors = np.linalg.eig(product)
print(eigen_values.shape)
print(eigen_vectors.shape)

prod = np.dot(eigen_vectors, arr1)
print(prod.shape)
for c in range(0,5):
    B = np.reshape(prod[c], (168,138))
    plt.imshow(B, cmap="gray")
    plt.show()

    

########
# print("poop")
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import GridSearchCV
# from sklearn.datasets import fetch_lfw_people
# from sklearn.metrics import classification_report
# from sklearn.metrics import confusion_matrix
# from sklearn.decomposition import PCA
# from sklearn.svm import SVC

# # introspect the images arrays to find the shapes (for plotting)
# n_samples, h, w = lfw_people.images.shape

# # for machine learning we use the 2 data directly (as relative pixel
# # positions info is ignored by this model)
# X = lfw_people.data
# n_features = X.shape[1]

# # the label to predict is the id of the person
# y = lfw_people.target
# target_names = lfw_people.target_names
# n_classes = target_names.shape[0]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# n_components = 30

# print("Extracting the top %d eigenfaces from %d faces"
#       % (n_components, X_train.shape[0]))
# t0 = time()
# pca = PCA(n_components=n_components, svd_solver='randomized',
#           whiten=True).fit(X_train)
# print("done in %0.3fs" % (time() - t0))

# eigenfaces = pca.components_.reshape((n_components, h, w))

# plt.imshow(eigenfaces, cmap="gray")
# plt.show()
# Out:
# [[ 64.  59.  55. ...  75.  65.  59.]
#  [106. 108. 110. ...  88.  85.  84.]
#  [ 95.  93.  91. ... 109. 112. 112.]
#  ...
#  [ 84.  90.  95. ...  78.  68.  29.]
#  [ 74.  75.  78. ...  82.  81.  81.]
#  [ 38.  43.  47. ... 147. 149. 146.]]
# (30, 23184)
# (23184, 1)
# lol
# (30, 23184)
# Arr
# (30, 23184)
# [[-30.36666667 -34.73333333 -40.1        ... -20.03333333 -31.96666667
#   -36.53333333]
#  [ 11.63333333  14.26666667  14.9        ...  -7.03333333 -11.96666667
#   -11.53333333]
#  [  0.63333333  -0.73333333  -4.1        ...  13.96666667  15.03333333
#    16.46666667]
#  ...
#  [-10.36666667  -3.73333333  -0.1        ... -17.03333333 -28.96666667
#   -66.53333333]
#  [-20.36666667 -18.73333333 -17.1        ... -13.03333333 -15.96666667
#   -14.53333333]
#  [-56.36666667 -50.73333333 -48.1        ...  51.96666667  52.03333333
#    50.46666667]]
# (30, 30)
# (30,)
# (30, 30)
# (30, 23184)

# %%
print(eigen_values)
print(eigen_values.shape)
sortedevals = np.sort(eigen_values)[::-1]
print(sortedevals)


tmparr = []
summ = 0
for elem in range(0,30):
    val = sortedevals[elem]
    summ = (summ + val)
    tmparr.append(summ)
tmparr = np.asarray(tmparr)
print(tmparr.shape)
maxval = np.max(tmparr)

tmparr = tmparr/maxval

indx=[]
for x in range(0,30):
    indx.append(x)
indx = np.asarray(indx)

print("eigen_vectors")
print(eigen_vectors.shape)
plt.figure(figsize = (20,10))
plt.grid()
plt.plot(indx, tmparr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()
# Out:
# [ 2.04242617e+04  8.00553511e+03  3.88940907e+03  3.26304064e+03
#   2.56232312e+03  2.01310927e+03  1.66873726e+03  1.46149845e+03
#   1.31101164e+03  1.17186656e+03  1.08273786e+03 -5.72747564e-13
#   8.56197919e+02  7.85258906e+02  7.05620699e+02  6.32486137e+02
#   5.89682132e+02  5.82830669e+02  1.63756993e+02  1.72587350e+02
#   2.06249571e+02  2.19195005e+02  5.07127736e+02  2.71263808e+02
#   3.24124526e+02  3.50934065e+02  3.37674476e+02  4.06841438e+02
#   4.41000044e+02  4.28087096e+02]
# (30,)
# [ 2.04242617e+04  8.00553511e+03  3.88940907e+03  3.26304064e+03
#   2.56232312e+03  2.01310927e+03  1.66873726e+03  1.46149845e+03
#   1.31101164e+03  1.17186656e+03  1.08273786e+03  8.56197919e+02
#   7.85258906e+02  7.05620699e+02  6.32486137e+02  5.89682132e+02
#   5.82830669e+02  5.07127736e+02  4.41000044e+02  4.28087096e+02
#   4.06841438e+02  3.50934065e+02  3.37674476e+02  3.24124526e+02
#   2.71263808e+02  2.19195005e+02  2.06249571e+02  1.72587350e+02
#   1.63756993e+02 -5.72747564e-13]
# (30,)
# eigen_vectors
# (30, 30)

# %%
newindx = []
for x in range(0,20):
    newindx.append(x)
newindx = np.asarray(newindx)

newarr = tmparr[:20]
newarr = np.asarray(newarr)


plt.figure(figsize = (20,10))
plt.grid()
plt.plot(newindx, newarr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors

for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(d_mtx)
    print(nearneighb.kneighbors(d_mtx[x].reshape(1, -1)))
# Out:
# (array([[   0.        , 5667.59031688]]), array([[0, 7]]))
# (array([[   0.       , 3980.4164355]]), array([[1, 4]]))
# (array([[   0.        , 5405.05541137]]), array([[2, 7]]))
# (array([[   0.        , 5517.08836253]]), array([[3, 1]]))
# (array([[   0.        , 3789.46368237]]), array([[4, 7]]))
# (array([[   0.        , 5112.63200319]]), array([[ 5, 28]]))
# (array([[   0.        , 6912.81823861]]), array([[6, 7]]))
# (array([[   0.        , 3542.70546334]]), array([[ 7, 25]]))
# (array([[   0.        , 7043.88117447]]), array([[8, 3]]))
# (array([[   0.        , 5075.22048782]]), array([[9, 7]]))
# (array([[   0.        , 7021.35207777]]), array([[10, 12]]))
# (array([[   0.        , 5646.70957284]]), array([[11, 13]]))
# (array([[   0.        , 7021.35207777]]), array([[12, 10]]))
# (array([[   0.        , 5646.70957284]]), array([[13, 11]]))
# (array([[   0.        , 9444.22278433]]), array([[14, 11]]))
# (array([[   0.        , 7465.63152051]]), array([[15, 17]]))
# (array([[   0.        , 7544.52019681]]), array([[16, 10]]))
# (array([[   0.        , 6909.53196678]]), array([[17, 21]]))
# (array([[   0.        , 5197.62965206]]), array([[18, 25]]))
# (array([[   0.        , 7987.46067283]]), array([[19, 10]]))
# (array([[   0.        , 5498.57827079]]), array([[20, 26]]))
# (array([[   0.        , 6909.53196678]]), array([[21, 17]]))
# (array([[   0.        , 5463.47325426]]), array([[22, 29]]))
# (array([[   0.        , 5631.17687522]]), array([[23, 28]]))
# (array([[   0.        , 7493.40483359]]), array([[24,  8]]))
# (array([[   0.        , 3542.70546334]]), array([[25,  7]]))
# (array([[   0.        , 3645.99835436]]), array([[26, 25]]))
# (array([[   0.        , 5444.43615079]]), array([[27, 28]]))
# (array([[   0.        , 4120.24004155]]), array([[28, 25]]))
# (array([[   0.        , 5282.26031165]]), array([[29, 25]]))

# %%
#x=np.dot((d_mtx[1]-mean),eigen_vectors[:,1])

eigenmtx = []

for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy=mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,20):
        tempvar = dcopy[value]
        tempvar = tempvar[:, np.newaxis]
    #     print(tempvar.shape)
    #     print(meancopy.shape)
        y=tempvar-meancopy
        mult = prod[num]
        mult = mult[:, np.newaxis]
        a1=np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final = mean + total
    eigenmtx.append(final)
    B = np.reshape(final, (168,138))
    plt.imshow(B, cmap="gray")
    plt.show()

eigenmtx = np.asarray(eigenmtx)
eigenmtx = np.squeeze(eigenmtx)
print(eigenmtx.shape)

from sklearn.neighbors import NearestNeighbors

for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(eigenmtx)
    print(nearneighb.kneighbors(eigenmtx[x].reshape(1, -1)))
# Out:
# (30, 23184)
# (array([[0.00000000e+00, 3.79071601e+11]]), array([[0, 3]]))
# (array([[0.00000000e+00, 1.27659552e+11]]), array([[1, 7]]))
# (array([[0.00000000e+00, 2.72332036e+11]]), array([[ 2, 26]]))
# (array([[0.00000000e+00, 3.79071601e+11]]), array([[3, 0]]))
# (array([[0.0000000e+00, 1.3550872e+11]]), array([[ 4, 25]]))
# (array([[0.0000000e+00, 3.0222508e+11]]), array([[ 5, 23]]))
# (array([[0.00000000e+00, 3.87394578e+11]]), array([[6, 9]]))
# (array([[0.00000000e+00, 1.27659552e+11]]), array([[7, 1]]))
# (array([[0.00000000e+00, 4.40017706e+11]]), array([[ 8, 24]]))
# (array([[0.00000000e+00, 1.71946797e+11]]), array([[9, 1]]))
# (array([[0.00000000e+00, 5.09011075e+11]]), array([[10, 16]]))
# (array([[0.00000000e+00, 3.12494576e+11]]), array([[11, 13]]))
# (array([[0.0000000e+00, 5.1373666e+11]]), array([[12, 19]]))
# (array([[0.00000000e+00, 3.12494576e+11]]), array([[13, 11]]))
# (array([[0.00000000e+00, 5.21210675e+11]]), array([[14, 16]]))
# (array([[0.00000000e+00, 3.56282418e+11]]), array([[15, 21]]))
# (array([[0.00000000e+00, 4.24951403e+11]]), array([[16, 19]]))
# (array([[0.00000000e+00, 1.01347917e+12]]), array([[17, 15]]))
# (array([[0.00000000e+00, 2.12181315e+11]]), array([[18,  9]]))
# (array([[0.00000000e+00, 4.24951403e+11]]), array([[19, 16]]))
# (array([[0.00000000e+00, 3.64592748e+11]]), array([[20,  5]]))
# (array([[0.00000000e+00, 3.56282418e+11]]), array([[21, 15]]))
# (array([[0.00000000e+00, 3.71454146e+11]]), array([[22, 27]]))
# (array([[0.0000000e+00, 3.0222508e+11]]), array([[23,  5]]))
# (array([[0.00000000e+00, 4.40017706e+11]]), array([[24,  8]]))
# (array([[0.0000000e+00, 1.3550872e+11]]), array([[25,  4]]))
# (array([[0.00000000e+00, 1.61005914e+11]]), array([[26,  4]]))
# (array([[0.00000000e+00, 2.24623785e+11]]), array([[27, 29]]))
# (array([[0.00000000e+00, 3.61152725e+11]]), array([[28,  5]]))
# (array([[0.00000000e+00, 2.24623785e+11]]), array([[29, 27]]))
