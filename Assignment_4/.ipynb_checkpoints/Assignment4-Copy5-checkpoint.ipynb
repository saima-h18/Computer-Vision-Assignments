# %% [markdown]
# ## <center> ECSE 415 - Intro to Computer Vision </center>
# ### <center> Assignment 4</center> <center> Saima Haneef - 260744058 </center>

# %%
import cv2
import matplotlib.pyplot as plt
import math
import numpy as np
import random
import os

# %% [markdown]
# ### 1

# %%
path1='./train_set/dwight/'
name = []

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("dwight")
    p = x.flatten()
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %%
path1='./train_set/pam/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("pam")
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %%
path1='./train_set/jim/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("jim")
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %% [markdown]
# ### 2

# %%
path1='./train_set/dwight/'

d_mtx = np.empty((30, len(p)))
val = 0
# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
        
path2='./train_set/pam/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path2))):
    x = cv2.cvtColor(cv2.imread(path2+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1

        
path3='./train_set/jim/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path3))):
    x = cv2.cvtColor(cv2.imread(path3+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
    
print(d_mtx)
print(d_mtx.shape)


mean = np.mean(d_mtx, axis=0)
mean = mean[:, np.newaxis]
print(mean.shape)
Bmean = np.reshape(mean, (168,138))
plt.imshow(np.real(Bmean), cmap="gray")
plt.show()


# prod = np.dot(eigen_vectors, d_mtx)
arr1 = np.empty((30, len(p)))
print("lol")
print(d_mtx.shape)
# for x in range(0, len(d_mtx)):
#     temp = d_mtx[x]-mean.T
#     arr1[x] = temp
arr1 = d_mtx - mean.T
print("Arr")
print(arr1.shape)
print(arr1)

product = np.dot(arr1, arr1.T)
# product = np.cov(arr1)
product = product
print(product.shape)

eigen_values, eigen_vectors = np.linalg.eig(product)
print(eigen_values.shape)
print(eigen_vectors.shape)
evals = eigen_values.copy()
eigen_values = eigen_values[:, np.newaxis]

    
print(eigen_values)

prod = np.dot(eigen_vectors, arr1)
# print(eigen_values)
eigen_values = np.sqrt((eigen_values), dtype=np.cdouble)
print(eigen_values)
prod = prod/eigen_values
print(prod.shape)


for c in range(0,5):
    B = np.reshape(prod[c], (168,138))
    plt.imshow(np.real(B), cmap="gray")
    plt.show()
# Out:
# [[ 64.  59.  55. ...  75.  65.  59.]
#  [106. 108. 110. ...  88.  85.  84.]
#  [ 95.  93.  91. ... 109. 112. 112.]
#  ...
#  [ 35.  51.  72. ... 211. 210. 198.]
#  [ 11.  10.  10. ...  57.  58.  58.]
#  [ 74.  75.  78. ...  82.  81.  81.]]
# (33, 23184)
# (23184, 1)
# lol
# (33, 23184)
# Arr
# (33, 23184)
# [[-1.50000000e+01 -1.60909091e+01 -2.05757576e+01 ... -1.99696970e+01
#   -3.09696970e+01 -3.87878788e+01]
#  [ 2.70000000e+01  3.29090909e+01  3.44242424e+01 ... -6.96969697e+00
#   -1.09696970e+01 -1.37878788e+01]
#  [ 1.60000000e+01  1.79090909e+01  1.54242424e+01 ...  1.40303030e+01
#    1.60303030e+01  1.42121212e+01]
#  ...
#  [-4.40000000e+01 -2.40909091e+01 -3.57575758e+00 ...  1.16030303e+02
#    1.14030303e+02  1.00212121e+02]
#  [-6.80000000e+01 -6.50909091e+01 -6.55757576e+01 ... -3.79696970e+01
#   -3.79696970e+01 -3.97878788e+01]
#  [-5.00000000e+00 -9.09090909e-02  2.42424242e+00 ... -1.29696970e+01
#   -1.49696970e+01 -1.67878788e+01]]
# (33, 33)
# (33,)
# (33, 33)
# [[4.69717184e+08]
#  [2.10138548e+08]
#  [1.54230992e+08]
#  [8.12207345e+07]
#  [6.74845255e+07]
#  [5.12970731e+07]
#  [4.72670761e+07]
#  [3.82576092e+07]
#  [3.28796306e+07]
#  [3.16353613e+07]
#  [2.82568412e+07]
#  [2.63241486e+07]
#  [6.46810411e-10]
#  [2.43735660e+07]
#  [2.27332562e+07]
#  [2.12112038e+07]
#  [1.92147367e+06]
#  [3.51569711e+06]
#  [1.86571568e+07]
#  [1.77159999e+07]
#  [1.73889663e+07]
#  [5.18260812e+06]
#  [5.75047126e+06]
#  [1.49168208e+07]
#  [1.44632860e+07]
#  [1.29262636e+07]
#  [7.57918278e+06]
#  [7.41766228e+06]
#  [8.50198693e+06]
#  [9.17195232e+06]
#  [1.00607456e+07]
#  [1.09217542e+07]
#  [1.07488025e+07]]
# [[2.16729598e+04+0.j]
#  [1.44961563e+04+0.j]
#  [1.24189771e+04+0.j]
#  [9.01225469e+03+0.j]
#  [8.21489656e+03+0.j]
#  [7.16219750e+03+0.j]
#  [6.87510553e+03+0.j]
#  [6.18527357e+03+0.j]
#  [5.73407627e+03+0.j]
#  [5.62453209e+03+0.j]
#  [5.31571643e+03+0.j]
#  [5.13070645e+03+0.j]
#  [2.54324677e-05+0.j]
#  [4.93695919e+03+0.j]
#  [4.76794046e+03+0.j]
#  [4.60556227e+03+0.j]
#  [1.38617231e+03+0.j]
#  [1.87501923e+03+0.j]
#  [4.31939310e+03+0.j]
#  [4.20903789e+03+0.j]
#  [4.17000795e+03+0.j]
#  [2.27653424e+03+0.j]
#  [2.39801402e+03+0.j]
#  [3.86223002e+03+0.j]
#  [3.80306272e+03+0.j]
#  [3.59531134e+03+0.j]
#  [2.75303156e+03+0.j]
#  [2.72353856e+03+0.j]
#  [2.91581668e+03+0.j]
#  [3.02852313e+03+0.j]
#  [3.17186784e+03+0.j]
#  [3.30480774e+03+0.j]
#  [3.27853664e+03+0.j]]
# (33, 23184)

# %%
sortedevals = np.sort(evals)[::-1]
print(sortedevals)

tmparr = []
summ = 0
for elem in range(0,30):
    val = sortedevals[elem]
    summ = (summ + val)
    tmparr.append(summ)
tmparr = np.asarray(tmparr)
print(tmparr.shape)
maxval = np.max(tmparr)
print(tmparr)
tmparr = tmparr/maxval

indx=[]
for x in range(0,30):
    indx.append(x)
indx = np.asarray(indx)

print("eigen_vectors")
print(eigen_vectors.shape)
plt.figure(figsize = (20,10))
plt.grid()
plt.plot(indx, tmparr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()
# Out:
# [4.69717184e+08 2.10138548e+08 1.54230992e+08 8.12207345e+07
#  6.74845255e+07 5.12970731e+07 4.72670761e+07 3.82576092e+07
#  3.28796306e+07 3.16353613e+07 2.82568412e+07 2.63241486e+07
#  2.43735660e+07 2.27332562e+07 2.12112038e+07 1.86571568e+07
#  1.77159999e+07 1.73889663e+07 1.49168208e+07 1.44632860e+07
#  1.29262636e+07 1.09217542e+07 1.07488025e+07 1.00607456e+07
#  9.17195232e+06 8.50198693e+06 7.57918278e+06 7.41766228e+06
#  5.75047126e+06 5.18260812e+06 3.51569711e+06 1.92147367e+06
#  6.46810411e-10]
# (33,)
# [4.69717184e+08 6.79855732e+08 8.34086725e+08 9.15307459e+08
#  9.82791985e+08 1.03408906e+09 1.08135613e+09 1.11961374e+09
#  1.15249337e+09 1.18412874e+09 1.21238558e+09 1.23870973e+09
#  1.26308329e+09 1.28581655e+09 1.30702775e+09 1.32568491e+09
#  1.34340091e+09 1.36078987e+09 1.37570669e+09 1.39016998e+09
#  1.40309624e+09 1.41401800e+09 1.42476680e+09 1.43482755e+09
#  1.44399950e+09 1.45250149e+09 1.46008067e+09 1.46749833e+09
#  1.47324880e+09 1.47843141e+09 1.48194711e+09 1.48386858e+09
#  1.48386858e+09]
# eigen_vectors
# (33, 33)

# %%
newindx = []
for x in range(0,20):
    newindx.append(x)
newindx = np.asarray(newindx)

newarr = tmparr[:20]
newarr = np.asarray(newarr)


plt.figure(figsize = (20,10))
plt.grid()
plt.plot(newindx, newarr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors

name = np.asarray(name)
indices = np.empty((30,2))
right = 0
accuracy = 0 
for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(d_mtx)
    indices[x]=((nearneighb.kneighbors(d_mtx[x].reshape(1, -1)))[1])
    
    if name[int(indices[x][0])] == name[int(indices[x][1])]:
        right = right+1
        
accuracy = right/30
print(accuracy)
# Out:
# 0.6363636363636364

# %%
#x=np.dot((d_mtx[1]-mean),eigen_vectors[:,1])

eigenmtx = []

for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy = mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,30):
        tempvar = dcopy[value]
        tempvar = tempvar[:, np.newaxis]
        y = tempvar-meancopy
        mult = np.real(prod[num])
        mult = mult[:, np.newaxis]
        a1 = np.dot(y.T,mult)
        val = (a1*mult)
        total = total+val
    final = mean + total
    eigenmtx.append(final)
    B = np.reshape(final, (168,138))
    plt.imshow(B, cmap="gray")
    plt.show()

eigenmtx = np.asarray(eigenmtx)
eigenmtx = np.squeeze(eigenmtx)
print(eigenmtx.shape)

from sklearn.neighbors import NearestNeighbors

name = np.asarray(name)
indices = np.empty((30,2))
right = 0
accuracy = 0 
for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(eigenmtx)
    indices[x]=((nearneighb.kneighbors(eigenmtx[x].reshape(1, -1)))[1])
    
    if name[int(indices[x][0])] == name[int(indices[x][1])]:
        right = right+1
        
accuracy = right/30
print(accuracy)
# Out:
# (33, 23184)
# 0.3333333333333333

# %%
path4='./train_set/group1.jpg'

image = cv2.cvtColor(cv2.imread(path4),cv2.COLOR_BGR2GRAY)
plt.imshow(image, cmap = "gray")
plt.show()
plt.figure(figsize=(20,20))


#50,50,39000
#45,45,32000
list1=[]
list2=[]
counter = 0
copy = image.copy()
stridex = 45 #45
stridey = 45 #45
(width, height) = (138,168) # window size
count=0
for y1 in range(0, image.shape[0]-stridey, stridex):
    for x1 in range(0, image.shape[1]-stridex, stridey):
        window = image[y1:y1+height, x1:x1+width]
        # disregard windows that are not the appropriate size
        if window.shape[0]!= 168 or window.shape[1]!=138:
            continue
        
        window = window.flatten()
        window = window[:,np.newaxis]
        for value in range(0,30):
            dcopy = d_mtx.copy()
            meancopy = mean
            total = np.zeros(23184)
            total = total.T
            total = total[:, np.newaxis]
            for num in range(0,30):
                y = window-meancopy
                mult = np.real(prod[num])
                mult = mult[:, np.newaxis]
                a1 = np.dot(y.T,mult)
                val=(a1*mult)
                total = total+val
            final = mean + total
    
        # Compute euclidean distance
        distarr = []
        for x in range(0,30):
            distance = np.linalg.norm(final.T-eigenmtx[x])
            distarr.append(distance)
        for x in distarr:
            if x<35000:
                bool=True
                
        # different RGB values to present different colored boxes
        rgb = [(255,255,255),(255,255,0),(255, 0, 255),(255, 0, 0)]
        # if distance is less than a certain amount then, create a box around the detected image
        if bool==True:
            patch = image[y1:y1 + height, x1:x1+width]
            plt.figure(figsize=(5,5))
            plt.imshow(patch)
            plt.show()
            copy = cv2.rectangle(copy, (x1, y1), (x1 + width, y1 + height), (rgb[count]), 2) # draw rectangle on image
            list1.append(x1)
            list2.append(y1)
            bool=False
            counter+=1
#7 or 14 for jim
#7,10,20
print(counter)
plt.figure(figsize=(50,50))
plt.imshow(copy)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-14768e5d0cda> in <module>
#      38                 a1 = np.dot(y.T,mult)
#      39                 val=(a1*mult)
# ---> 40                 total = total+val
#      41             final = mean + total
#      42
#
# KeyboardInterrupt:

# %%
patch1 = image[list2[14]:list2[14] + height, list1[14]:list1[14]+width]
patch2 = image[list2[10]:list2[10] + height, list1[10]:list1[10]+width]
patch3 = image[list2[26]:list2[26] + height, list1[26]:list1[26]+width]
plt.imshow(patch1)
plt.show()

plt.imshow(patch2)
plt.show()

plt.imshow(patch3)
plt.show()
patch1 = patch1.flatten()
patch2 = patch2.flatten()
patch3 = patch3.flatten()
patch1 = np.asarray(patch1)
patch2 = np.asarray(patch2)
patch3 = np.asarray(patch3)
patch1 = patch1[:,np.newaxis]
patch2 = patch2[:,np.newaxis]
patch3 = patch3[:,np.newaxis]

for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy = mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,30):
        y = patch1-meancopy
        mult = np.real(prod[num])
        mult = mult[:, np.newaxis]
        a1 = np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final1 = mean + total

# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(final1.T-eigenmtx[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)

#2
for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy = mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,30):
        y = patch2-meancopy
        mult = np.real(prod[num])
        mult = mult[:, np.newaxis]
        a1 = np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final2 = mean + total

# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(final2.T-eigenmtx[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)


#3
for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy = mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,30):
        y = patch3-meancopy
        mult = np.real(prod[num])
        mult = mult[:, np.newaxis]
        a1 = np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final3 = mean + total

# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(final3.T-eigenmtx[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)
