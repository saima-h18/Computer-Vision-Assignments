# %% [markdown]
# ## <center> ECSE 415 - Intro to Computer Vision </center>
# ### <center> Assignment 4</center> <center> Saima Haneef - 260744058 </center>

# %%
import cv2
import matplotlib.pyplot as plt
import math
import numpy as np
import random
import os

# %% [markdown]
# ### 1

# %%
path1='./train_set/dwight/'
name = []

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("dwight")
    p = x.flatten()
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %%
path1='./train_set/pam/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("pam")
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %%
path1='./train_set/jim/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("jim")
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %% [markdown]
# ### 2

# %%
path1='./train_set/dwight/'

d_mtx = np.empty((30, len(p)))
val = 0
# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
        
path2='./train_set/pam/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path2))):
    x = cv2.cvtColor(cv2.imread(path2+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1

        
path3='./train_set/jim/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path3))):
    x = cv2.cvtColor(cv2.imread(path3+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
    
print(d_mtx)
print(d_mtx.shape)


mean = np.mean(d_mtx, axis=0)
mean = mean[:, np.newaxis]
print(mean.shape)
Bmean = np.reshape(mean, (168,138))
plt.imshow(np.real(Bmean), cmap="gray")
plt.show()


# prod = np.dot(eigen_vectors, d_mtx)
arr1 = np.empty((30, len(p)))
print("lol")
print(d_mtx.shape)
# for x in range(0, len(d_mtx)):
#     temp = d_mtx[x]-mean.T
#     arr1[x] = temp
arr1 = d_mtx - mean.T
print("Arr")
print(arr1.shape)
print(arr1)

product = np.dot(arr1, arr1.T)
# product = np.cov(arr1)
product = product
print(product.shape)

eigen_values, eigen_vectors = np.linalg.eig(product)
print(eigen_values.shape)
print(eigen_vectors.shape)
evals = eigen_values.copy()
eigen_values = eigen_values[:, np.newaxis]

    
print(eigen_values)

prod = np.dot(eigen_vectors, arr1)
# print(eigen_values)
eigen_values = np.sqrt((eigen_values), dtype=np.cdouble)
print(eigen_values)
prod = prod/eigen_values
print(prod.shape)


for c in range(0,5):
    B = np.reshape(prod[c], (168,138))
    plt.imshow(np.real(B), cmap="gray")
    plt.show()
# Out:
# [[ 64.  59.  55. ...  75.  65.  59.]
#  [106. 108. 110. ...  88.  85.  84.]
#  [ 95.  93.  91. ... 109. 112. 112.]
#  ...
#  [ 80.  81.  83. ...  75.  74.  73.]
#  [ 35.  51.  72. ... 211. 210. 198.]
#  [ 11.  10.  10. ...  57.  58.  58.]]
# (30, 23184)
# (23184, 1)
# lol
# (30, 23184)
# Arr
# (30, 23184)
# [[-14.4        -17.93333333 -23.86666667 ... -22.33333333 -32.9
#   -40.93333333]
#  [ 27.6         31.06666667  31.13333333 ...  -9.33333333 -12.9
#   -15.93333333]
#  [ 16.6         16.06666667  12.13333333 ...  11.66666667  14.1
#    12.06666667]
#  ...
#  [  1.6          4.06666667   4.13333333 ... -22.33333333 -23.9
#   -26.93333333]
#  [-43.4        -25.93333333  -6.86666667 ... 113.66666667 112.1
#    98.06666667]
#  [-67.4        -66.93333333 -68.86666667 ... -40.33333333 -39.9
#   -41.93333333]]
# (30, 30)
# (30,)
# (30, 30)
# [[ 4.23619194e+08]
#  [ 1.88251041e+08]
#  [ 1.44286107e+08]
#  [ 6.86708310e+07]
#  [ 5.86069947e+07]
#  [ 4.54254028e+07]
#  [ 4.35497767e+07]
#  [ 3.34246113e+07]
#  [ 3.10899059e+07]
#  [ 2.95379731e+07]
#  [-1.97701057e-08]
#  [ 2.59686142e+07]
#  [ 2.35280421e+07]
#  [ 2.27994570e+07]
#  [ 1.98179796e+07]
#  [ 3.48845021e+06]
#  [ 1.79788847e+07]
#  [ 1.74225510e+07]
#  [ 1.60188369e+07]
#  [ 1.44151984e+07]
#  [ 1.34735037e+07]
#  [ 5.21335332e+06]
#  [ 5.73627037e+06]
#  [ 6.04959481e+06]
#  [ 1.19535257e+07]
#  [ 7.59670175e+06]
#  [ 1.08683440e+07]
#  [ 9.08044896e+06]
#  [ 1.00842663e+07]
#  [ 8.47365923e+06]]
# [[20582.01140729+0.j        ]
#  [13720.46068729+0.j        ]
#  [12011.91518976+0.j        ]
#  [ 8286.78653267+0.j        ]
#  [ 7655.52053507+0.j        ]
#  [ 6739.83699889+0.j        ]
#  [ 6599.22545948+0.j        ]
#  [ 5781.40219404+0.j        ]
#  [ 5575.83230736+0.j        ]
#  [ 5434.88482587+0.j        ]
#  [    0.        +0.00014061j]
#  [ 5095.94094928+0.j        ]
#  [ 4850.57132159+0.j        ]
#  [ 4774.87768962+0.j        ]
#  [ 4451.73893864+0.j        ]
#  [ 1867.73933151+0.j        ]
#  [ 4240.15149353+0.j        ]
#  [ 4174.03294105+0.j        ]
#  [ 4002.35391798+0.j        ]
#  [ 3796.7352354 +0.j        ]
#  [ 3670.62715226+0.j        ]
#  [ 2283.27688195+0.j        ]
#  [ 2395.05122451+0.j        ]
#  [ 2459.59240788+0.j        ]
#  [ 3457.38712323+0.j        ]
#  [ 2756.21148466+0.j        ]
#  [ 3296.71714874+0.j        ]
#  [ 3013.37832951+0.j        ]
#  [ 3175.57338883+0.j        ]
#  [ 2910.95503729+0.j        ]]
# (30, 23184)

# %%
sortedevals = np.sort(evals)[::-1]
print(sortedevals)

tmparr = []
summ = 0
for elem in range(0,30):
    val = sortedevals[elem]
    summ = (summ + val)
    tmparr.append(summ)
tmparr = np.asarray(tmparr)
print(tmparr.shape)
maxval = np.max(tmparr)
print(tmparr)
tmparr = tmparr/maxval

indx=[]
for x in range(0,30):
    indx.append(x)
indx = np.asarray(indx)

print("eigen_vectors")
print(eigen_vectors.shape)
plt.figure(figsize = (20,10))
plt.grid()
plt.plot(indx, tmparr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()
# Out:
# [ 4.23619194e+08  1.88251041e+08  1.44286107e+08  6.86708310e+07
#   5.86069947e+07  4.54254028e+07  4.35497767e+07  3.34246113e+07
#   3.10899059e+07  2.95379731e+07  2.59686142e+07  2.35280421e+07
#   2.27994570e+07  1.98179796e+07  1.79788847e+07  1.74225510e+07
#   1.60188369e+07  1.44151984e+07  1.34735037e+07  1.19535257e+07
#   1.08683440e+07  1.00842663e+07  9.08044896e+06  8.47365923e+06
#   7.59670175e+06  6.04959481e+06  5.73627037e+06  5.21335332e+06
#   3.48845021e+06 -1.97701057e-08]
# (30,)
# [4.23619194e+08 6.11870235e+08 7.56156342e+08 8.24827173e+08
#  8.83434167e+08 9.28859570e+08 9.72409347e+08 1.00583396e+09
#  1.03692386e+09 1.06646184e+09 1.09243045e+09 1.11595849e+09
#  1.13875795e+09 1.15857593e+09 1.17655481e+09 1.19397737e+09
#  1.20999620e+09 1.22441140e+09 1.23788490e+09 1.24983843e+09
#  1.26070677e+09 1.27079104e+09 1.27987149e+09 1.28834515e+09
#  1.29594185e+09 1.30199145e+09 1.30772772e+09 1.31294107e+09
#  1.31642952e+09 1.31642952e+09]
# eigen_vectors
# (30, 30)

# %%
newindx = []
for x in range(0,20):
    newindx.append(x)
newindx = np.asarray(newindx)

newarr = tmparr[:20]
newarr = np.asarray(newarr)


plt.figure(figsize = (20,10))
plt.grid()
plt.plot(newindx, newarr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors

name = np.asarray(name)
indices = np.empty((30,2))
right = 0
accuracy = 0 
for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(d_mtx)
    indices[x]=((nearneighb.kneighbors(d_mtx[x].reshape(1, -1)))[1])
    
    if name[int(indices[x][0])] == name[int(indices[x][1])]:
        right = right+1
        
accuracy = right/30
print(accuracy)
# Out:
# 0.6666666666666666

# %%
#x=np.dot((d_mtx[1]-mean),eigen_vectors[:,1])

eigenmtx = []

eigenmatrix = np.empty((30,30))
for num in range(0,30):
    ex = arr1[num]
    ex = ex[:,np.newaxis]
    ex = ex.T
    dproj = np.dot(ex,prod.T)
    eigenmatrix[num] = dproj
    
prod_t = prod.T

reconstruct = np.empty((30,138*168))

for val in range(0,30):
    a1 = eigenmatrix[val]
    a1 = a1[:,np.newaxis]
    a1 = a1.T
    tempnum = np.dot(a1,prod)
    sumval = tempnum + mean.T
    reconstruct[num] = sumval

print(reconstruct)

from sklearn.neighbors import NearestNeighbors

name = np.asarray(name)
indices = np.empty((30,2))
right = 0
accuracy = 0 
for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(reconstruct)
    indices[x]=((nearneighb.kneighbors(reconstruct[x].reshape(1, -1)))[1])
    
    if name[int(indices[x][0])] == name[int(indices[x][1])]:
        right = right+1
        
accuracy = right/30
print(accuracy)

# for value in range(0,30):
#     dcopy = d_mtx.copy()
#     meancopy = mean
#     total = np.zeros(23184)
#     total = total.T
#     total = total[:, np.newaxis]
#     for num in range(0,30):
#         tempvar = dcopy[value]
#         tempvar = tempvar[:, np.newaxis]
#         y = tempvar-meancopy
#         mult = np.real(prod[num])
#         mult = mult[:, np.newaxis]
#         a1 = np.dot(y.T,mult)
#         val = (a1*mult)
#         total = total+val
#     final = mean + total
#     eigenmtx.append(final)
#     B = np.reshape(final, (168,138))
#     plt.imshow(B, cmap="gray")
#     plt.show()

# eigenmtx = np.asarray(eigenmtx)
# eigenmtx = np.squeeze(eigenmtx)
# print(eigenmtx.shape)

# from sklearn.neighbors import NearestNeighbors

# name = np.asarray(name)
# indices = np.empty((30,2))
# right = 0
# accuracy = 0 
# for x in range(0,30):
#     nearneighb = NearestNeighbors(n_neighbors=2)
#     nearneighb.fit(eigenmtx)
#     indices[x]=((nearneighb.kneighbors(eigenmtx[x].reshape(1, -1)))[1])
    
#     if name[int(indices[x][0])] == name[int(indices[x][1])]:
#         right = right+1
        
# accuracy = right/30
# print(accuracy)
# Out:
# [[  -14.4          -17.93333333   -23.86666667 ...   -22.33333333
#     -32.9          -40.93333333]
#  [   27.6           31.06666667    31.13333333 ...    -9.33333333
#     -12.9          -15.93333333]
#  [   16.6           16.06666667    12.13333333 ...    11.66666667
#      14.1           12.06666667]
#  ...
#  [    1.6            4.06666667     4.13333333 ...   -22.33333333
#     -23.9          -26.93333333]
#  [  -43.4          -25.93333333    -6.86666667 ...   113.66666667
#     112.1           98.06666667]
#  [-1499.5206488  -1226.63381635 -1361.3593352  ...  -173.12870368
#    -411.02700279  -638.07919011]]
# 0.6666666666666666
# /opt/anaconda3/envs/my_root/lib/python3.6/site-packages/ipykernel_launcher.py:11: ComplexWarning: Casting complex values to real discards the imaginary part
#   # This is added back by InteractiveShellApp.init_path()
# /opt/anaconda3/envs/my_root/lib/python3.6/site-packages/ipykernel_launcher.py:23: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
path4='./train_set/group.jpg'

image = cv2.cvtColor(cv2.imread(path4),cv2.COLOR_BGR2GRAY)
plt.imshow(image, cmap = "gray")
plt.show()
plt.figure(figsize=(20,20))


#50,50,39000
#45,45,32000
list1=[]
list2=[]
counter = 0
copy = image.copy()
stridex = 50 #45
stridey = 10 #45
(width, height) = (138,168) # window size
count=0
for y1 in range(0, image.shape[0]-stridey, stridex):
    for x1 in range(0, image.shape[1]-stridex, stridey):
        window = image[y1:y1+height, x1:x1+width]
        # disregard windows that are not the appropriate size
        if window.shape[0]!= 168 or window.shape[1]!=138:
            continue
        
        window = window.flatten()
        window = window[:,np.newaxis]
#         print(window.shape)
#         print(mean.shape)

        total = np.zeros(23184)
        total = total.T
        total = total[:, np.newaxis]
        for num in range(0,30):
            y = window-meancopy
            mult = np.real(prod[num])
            mult = mult[:, np.newaxis]
            a1 = np.dot(y.T,mult)
            val=(a1*mult)
            total = total+val
        final = mean + total
        
        # Compute euclidean distance
        distarr = np.empty((30,1),dtype='double')
        for x in range(0,30):
            distance = np.linalg.norm(final.T-reconstruct[x])
            distarr[x] = (distance)
        distarr = distarr / max(distarr)
#         print(distarr)
        for x in distarr:
            if x<0.14:
                bool=True
                
        # different RGB values to present different colored boxes
        rgb = [(255,255,255),(255,255,0),(255, 0, 255),(255, 0, 0)]
        # if distance is less than a certain amount then, create a box around the detected image
        if bool==True:
            patch = image[y1:y1 + height, x1:x1+width]
            plt.figure(figsize=(5,5))
            plt.imshow(patch)
            plt.text(x=0,y=0,s=counter)
            plt.show()
            copy = cv2.rectangle(copy, (x1, y1), (x1 + width, y1 + height), (rgb[count]), 2) # draw rectangle on image
            list1.append(x1)
            list2.append(y1)
            bool=False
            counter+=1
#7 or 14 for jim
#7,10,20
print(counter)
plt.figure(figsize=(50,50))
plt.imshow(copy, cmap='gray')
plt.show()
# Out:
# 7

# %%
copiedimg = image.copy()
copiedimg = cv2.rectangle(copiedimg, (list1[3], list2[3]), (list1[3] + width, list2[3] + height), (rgb[count]), 2) # draw rectangle on image
copiedimg = cv2.rectangle(copiedimg, (list1[11], list2[11]), (list1[11] + width, list2[11] + height), (rgb[count]), 2) # draw rectangle on image
copiedimg = cv2.rectangle(copiedimg, (list1[17], list2[17]), (list1[17] + width, list2[17] + height), (rgb[count]), 2) # draw rectangle on image
plt.figure(figsize=(50,50))
plt.imshow(copiedimg, cmap = "gray")
plt.show()

# %%
patch1 = image[list2[20]:list2[20] + height, list1[20]:list1[20]+width] #25 #35,36
patch2 = image[list2[26]:list2[26] + height, list1[26]:list1[26]+width] #41
patch3 = image[list2[54]:list2[54] + height, list1[54]:list1[54]+width]
plt.imshow(patch1, cmap='gray')
plt.show()

plt.imshow(patch2, cmap = 'gray')
plt.show()

plt.imshow(patch3, cmap = 'gray')
plt.show()
patch1 = patch1.flatten()
patch2 = patch2.flatten()
patch3 = patch3.flatten()
patch1 = np.asarray(patch1)
patch2 = np.asarray(patch2)
patch3 = np.asarray(patch3)
patch1 = patch1[:,np.newaxis]
patch2 = patch2[:,np.newaxis]
patch3 = patch3[:,np.newaxis]

# for value in range(0,30):
#     dcopy = d_mtx.copy()
#     meancopy = mean
#     total = np.zeros(23184)
#     total = total.T
#     total = total[:, np.newaxis]
#     for num in range(0,30):
#         y = patch1-meancopy
#         mult = np.real(prod[num])
#         mult = mult[:, np.newaxis]
#         a1 = np.dot(y.T,mult)
#         val=(a1*mult)
#         total = total+val
#     final1 = mean + total
print(patch1.shape)
print(prod.shape)
patch1 = patch1 - mean
patch10 = np.dot(patch1.T,prod.T)
print(patch10.shape)
# Compute euclidean distance

distarr = []
for x in range(0,30):
    distance = np.linalg.norm(patch10-eigenmatrix[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)


patch2 = patch2 - mean
patch10 = np.dot(patch2.T,prod.T)
# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(patch10-eigenmatrix[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)


patch3 = patch3 - mean
patch10 = np.dot(patch3.T,prod.T)
# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(patch10-eigenmatrix[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)
# Out:
# (23184, 1)
# (30, 23184)
# (1, 30)
# jim
# dwight
# pam

# %%
path4='./train_set/group.jpg'

image = cv2.cvtColor(cv2.imread(path4),cv2.COLOR_BGR2GRAY)
plt.imshow(image, cmap = "gray")
plt.show()
plt.figure(figsize=(20,20))


#50,50,39000
#45,45,32000
list1=[]
list2=[]
counter = 0
copy = image.copy()
stridex = 50 #45
stridey = 50 #45
(width, height) = (138,168) # window size
count=0
for y1 in range(0, image.shape[0]-stridey, stridex):
    for x1 in range(0, image.shape[1]-stridex, stridey):
        window = image[y1:y1+height, x1:x1+width]
        # disregard windows that are not the appropriate size
        if window.shape[0]!= 168 or window.shape[1]!=138:
            continue
        
        window = window.flatten()
        window = window[:,np.newaxis]
#         print(window.shape)
#         print(mean.shape)
        window = window - mean
        dproj = np.dot(window.T,prod.T)
        print(dproj.shape)
#         print(prod.shape)
#         final = np.dot(dproj,prod)
#         final = mean.T + final

        total = np.zeros(23184)
        total = total.T
        total = total[:, np.newaxis]
        for num in range(0,30):
            y = window-meancopy
            mult = np.real(prod[num])
            mult = mult[:, np.newaxis]
            a1 = np.dot(y.T,mult)
            val=(a1*mult)
            total = total+val
        final = mean + total
        
        # Compute euclidean distance
        distarr = np.empty((30,1),dtype='double')
        for x in range(0,30):
            distance = np.linalg.norm(dproj-eigenmatrix[x])
            distarr[x] = (distance)
        print(distarr)
        distarr = distarr / max(distarr)
        print(distarr)
        for x in distarr:
            if x<0.5:
                bool=True
                
        # different RGB values to present different colored boxes
        rgb = [(255,255,255),(255,255,0),(255, 0, 255),(255, 0, 0)]
        # if distance is less than a certain amount then, create a box around the detected image
        if bool==True:
            patch = image[y1:y1 + height, x1:x1+width]
            plt.figure(figsize=(5,5))
            plt.imshow(patch)
            plt.text(x=0,y=0,s=counter)
            plt.show()
            copy = cv2.rectangle(copy, (x1, y1), (x1 + width, y1 + height), (rgb[count]), 2) # draw rectangle on image
            list1.append(x1)
            list2.append(y1)
            bool=False
            counter+=1
#7 or 14 for jim
#7,10,20
print(counter)
plt.figure(figsize=(50,50))
plt.imshow(copy, cmap='gray')
plt.show()

# %%
patch1 = image[list2[13]:list2[13] + height, list1[13]:list1[13]+width] #25 #35,36
patch2 = image[list2[25]:list2[25] + height, list1[25]:list1[25]+width] #41
patch3 = image[list2[11]:list2[11] + height, list1[11]:list1[11]+width]
plt.imshow(patch1, cmap='gray')
plt.show()

plt.imshow(patch2, cmap = 'gray')
plt.show()

plt.imshow(patch3, cmap = 'gray')
plt.show()
patch1 = patch1.flatten()
patch2 = patch2.flatten()
patch3 = patch3.flatten()
patch1 = np.asarray(patch1)
patch2 = np.asarray(patch2)
patch3 = np.asarray(patch3)
patch1 = patch1[:,np.newaxis]
patch2 = patch2[:,np.newaxis]
patch3 = patch3[:,np.newaxis]

for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy = mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,30):
        y = patch1-meancopy
        mult = np.real(prod[num])
        mult = mult[:, np.newaxis]
        a1 = np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final1 = mean + total

# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(final1.T-eigenmtx[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)

#2
for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy = mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,30):
        y = patch2-meancopy
        mult = np.real(prod[num])
        mult = mult[:, np.newaxis]
        a1 = np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final2 = mean + total

# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(final2.T-eigenmtx[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)


#3
for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy = mean
    total = np.zeros(23184)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,30):
        y = patch3-meancopy
        mult = np.real(prod[num])
        mult = mult[:, np.newaxis]
        a1 = np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final3 = mean + total

# Compute euclidean distance
distarr = []
for x in range(0,30):
    distance = np.linalg.norm(final3.T-eigenmtx[x])
    distarr.append(distance)
minindx = distarr.index(min(distarr))
char = name[minindx]
print(char)
