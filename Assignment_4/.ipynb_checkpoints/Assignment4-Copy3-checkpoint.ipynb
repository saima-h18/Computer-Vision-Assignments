# %% [markdown]
# ## <center> ECSE 415 - Intro to Computer Vision </center>
# ### <center> Assignment 4</center> <center> Saima Haneef - 260744058 </center>

# %%
import cv2
import matplotlib.pyplot as plt
import math
import numpy as np
import random
import os

# %% [markdown]
# ### 1

# %%
path1='./train_set3/danny/'
name = []

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))+1):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("dwight")
    p = x.flatten()
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %%
path1='./train_set3/jesse/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))+1):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("pam")
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %%
path1='./train_set3/joey/'

n = 0
plt.figure(figsize=(20, 20))

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))+1):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    name.append("jim")
    plt.subplot(151+n%5)
    plt.imshow(x, cmap = "gray")
    n = n + 1 
    if (n%5 ==0 and n!=0):
        plt.show()
        plt.figure(figsize=(20, 20))

# %% [markdown]
# ### 2

# %%
path1='./train_set3/danny/'

d_mtx = np.empty((30, len(p)))
val = 0
# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path1))):
    x = cv2.cvtColor(cv2.imread(path1+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
        
path2='./train_set3/jesse/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path2))):
    x = cv2.cvtColor(cv2.imread(path2+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1

        
path3='./train_set3/joey/'

# add all feature maps to the array and then find the average to get the mean feature map
for i in range(1,len(os.listdir(path3))):
    x = cv2.cvtColor(cv2.imread(path3+ str(i)+'.jpg'),cv2.COLOR_BGR2GRAY)
    p = x.flatten()
    d_mtx[val] = p
    val=val+1
    
print(d_mtx)
print(d_mtx.shape)


mean = np.mean(d_mtx, axis=0)
mean = mean[:, np.newaxis]
print(mean.shape)
B = np.reshape(mean, (170,140))
plt.imshow(np.real(B), cmap="gray")
plt.show()


# prod = np.dot(eigen_vectors, d_mtx)
arr1 = np.empty((30, len(p)))
print("lol")
print(d_mtx.shape)
for x in range(0, len(d_mtx)):
    temp = d_mtx[x]-mean.T
    arr1[x] = temp
print("Arr")
print(arr1.shape)
print(arr1)

product = np.dot(arr1, arr1.T)
# product = np.cov(arr1)
# product = product/arr1.shape[1]
print(product.shape)

eigen_values, eigen_vectors = np.linalg.eig(product)
print(eigen_values.shape)
print(eigen_vectors.shape)
eigen_values = eigen_values[:, np.newaxis]

prod = np.dot(eigen_vectors, arr1)
print(eigen_values)
sqrteig = np.sqrt(eigen_values)
print(sqrteig)
prod = prod/sqrteig
print(prod.shape)

for c in range(0,5):
    B = np.reshape(prod[c], (170,140))
    plt.imshow(B, cmap="gray")
    plt.show()

    

########
# print("poop")
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import GridSearchCV
# from sklearn.datasets import fetch_lfw_people
# from sklearn.metrics import classification_report
# from sklearn.metrics import confusion_matrix
# from sklearn.decomposition import PCA
# from sklearn.svm import SVC

# # introspect the images arrays to find the shapes (for plotting)
# n_samples, h, w = lfw_people.images.shape

# # for machine learning we use the 2 data directly (as relative pixel
# # positions info is ignored by this model)
# X = lfw_people.data
# n_features = X.shape[1]

# # the label to predict is the id of the person
# y = lfw_people.target
# target_names = lfw_people.target_names
# n_classes = target_names.shape[0]
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# n_components = 30

# print("Extracting the top %d eigenfaces from %d faces"
#       % (n_components, X_train.shape[0]))
# t0 = time()
# pca = PCA(n_components=n_components, svd_solver='randomized',
#           whiten=True).fit(X_train)
# print("done in %0.3fs" % (time() - t0))

# eigenfaces = pca.components_.reshape((n_components, h, w))

# plt.imshow(eigenfaces, cmap="gray")
# plt.show()
# Out:
# [[2.10000000e+001 1.20000000e+001 1.80000000e+001 ... 1.02000000e+002
#   8.90000000e+001 1.08000000e+002]
#  [1.90000000e+001 1.90000000e+001 2.00000000e+001 ... 1.33000000e+002
#   1.37000000e+002 1.40000000e+002]
#  [3.10000000e+001 3.90000000e+001 4.90000000e+001 ... 1.30000000e+001
#   1.60000000e+001 1.90000000e+001]
#  ...
#  [7.29111856e-304 7.29111856e-304 7.29111856e-304 ... 7.29111856e-304
#   7.29111856e-304 7.29111856e-304]
#  [7.29111856e-304 7.29111856e-304 7.29111856e-304 ... 7.29111856e-304
#   7.29111856e-304 7.29111856e-304]
#  [7.29111856e-304 7.29111856e-304 7.29111856e-304 ... 7.29111856e-304
#   7.29111856e-304 7.29111856e-304]]
# (30, 23800)
# (23800, 1)
# lol
# (30, 23800)
# Arr
# (30, 23800)
# [[-24.3        -34.33333333 -30.         ...  11.93333333  -4.5
#    13.33333333]
#  [-26.3        -27.33333333 -28.         ...  42.93333333  43.5
#    45.33333333]
#  [-14.3         -7.33333333   1.         ... -77.06666667 -77.5
#   -75.66666667]
#  ...
#  [-45.3        -46.33333333 -48.         ... -90.06666667 -93.5
#   -94.66666667]
#  [-45.3        -46.33333333 -48.         ... -90.06666667 -93.5
#   -94.66666667]
#  [-45.3        -46.33333333 -48.         ... -90.06666667 -93.5
#   -94.66666667]]
# (30, 30)
# (30,)
# (30, 30)
# [[ 1.42813818e+09]
#  [ 2.28946928e+08]
#  [ 1.30175244e+08]
#  [ 1.24951759e+08]
#  [ 8.00253464e+07]
#  [ 7.67297898e+07]
#  [ 6.00819858e+07]
#  [ 5.37576812e+07]
#  [ 5.03730467e+07]
#  [ 4.13654245e+07]
#  [ 3.95355264e+07]
#  [ 3.63045391e+07]
#  [ 2.95648629e+07]
#  [ 2.52961105e+07]
#  [ 2.45405244e+07]
#  [ 2.26662907e+07]
#  [ 7.04624255e+06]
#  [ 8.87979335e+06]
#  [ 8.28241537e+06]
#  [ 1.08033619e+07]
#  [ 1.16508037e+07]
#  [ 1.98453780e+07]
#  [ 1.34020681e+07]
#  [ 1.45873459e+07]
#  [ 1.83391138e+07]
#  [ 1.65508864e+07]
#  [ 1.72398130e+07]
#  [ 2.46307371e-09]
#  [-1.22000580e-09]
#  [-5.27257170e-29]]
# [[3.77907156e+04]
#  [1.51309923e+04]
#  [1.14094366e+04]
#  [1.11781823e+04]
#  [8.94568871e+03]
#  [8.75955420e+03]
#  [7.75125704e+03]
#  [7.33196299e+03]
#  [7.09739718e+03]
#  [6.43159580e+03]
#  [6.28772824e+03]
#  [6.02532481e+03]
#  [5.43735808e+03]
#  [5.02952389e+03]
#  [4.95383936e+03]
#  [4.76091280e+03]
#  [2.65447595e+03]
#  [2.97989821e+03]
#  [2.87791858e+03]
#  [3.28684680e+03]
#  [3.41332736e+03]
#  [4.45481514e+03]
#  [3.66088351e+03]
#  [3.81933841e+03]
#  [4.28241916e+03]
#  [4.06827807e+03]
#  [4.15208538e+03]
#  [4.96293634e-05]
#  [           nan]
#  [           nan]]
# (30, 23800)
# /opt/anaconda3/envs/my_root/lib/python3.6/site-packages/ipykernel_launcher.py:66: RuntimeWarning: invalid value encountered in sqrt

# %%
sortedevals = np.sort(eigen_values)[::-1]


tmparr = []
summ = 0
for elem in range(0,30):
    val = sortedevals[elem]
    summ = (summ + val)
    tmparr.append(summ)
tmparr = np.asarray(tmparr)
print(tmparr.shape)
maxval = np.max(tmparr)

tmparr = tmparr/maxval

indx=[]
for x in range(0,30):
    indx.append(x)
indx = np.asarray(indx)

print("eigen_vectors")
print(eigen_vectors.shape)
plt.figure(figsize = (20,10))
plt.grid()
plt.plot(indx, tmparr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()
# Out:
# (30, 1)
# eigen_vectors
# (30, 30)

# %%
newindx = []
for x in range(0,20):
    newindx.append(x)
newindx = np.asarray(newindx)

newarr = tmparr[:20]
newarr = np.asarray(newarr)


plt.figure(figsize = (20,10))
plt.grid()
plt.plot(newindx, newarr)
plt.title("Normalized Cross Correlation Values as the Index of Patch in the right image is shifted")
plt.xlabel("Index of the patch in the Right Image")
plt.ylabel("Normalized Cross Correlation")
plt.show()

# %%
from sklearn.neighbors import NearestNeighbors

name = np.asarray(name)
indices = np.empty((30,2))
right = 0
accuracy = 0 
for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(d_mtx)
    indices[x]=((nearneighb.kneighbors(d_mtx[x].reshape(1, -1)))[1])
    
    if name[int(indices[x][0])] == name[int(indices[x][1])]:
        right = right+1
        
accuracy = right/30
print(accuracy)
# Out:
# 0.3

# %%
#x=np.dot((d_mtx[1]-mean),eigen_vectors[:,1])

eigenmtx = []

for value in range(0,30):
    dcopy = d_mtx.copy()
    meancopy=mean
    total = np.zeros(23800)
    total = total.T
    total = total[:, np.newaxis]
    for num in range(0,20):
        tempvar = dcopy[value]
        tempvar = tempvar[:, np.newaxis]
        y=tempvar-meancopy
        mult = prod[num]
        mult = mult[:, np.newaxis]
        a1=np.dot(y.T,mult)
        val=(a1*mult)
        total = total+val
    final = mean + total
    eigenmtx.append(final)
    B = np.reshape(final, (170,140))
    plt.imshow(B, cmap="gray")
    plt.show()

eigenmtx = np.asarray(eigenmtx)
eigenmtx = np.squeeze(eigenmtx)
print(eigenmtx.shape)

from sklearn.neighbors import NearestNeighbors

name = np.asarray(name)
indices = np.empty((30,2))
right = 0
accuracy = 0 
for x in range(0,30):
    nearneighb = NearestNeighbors(n_neighbors=2)
    nearneighb.fit(eigenmtx)
    indices[x]=((nearneighb.kneighbors(eigenmtx[x].reshape(1, -1)))[1])
    
    if name[int(indices[x][0])] == name[int(indices[x][1])]:
        right = right+1
        
accuracy = right/30
print(accuracy)
# Out:
# (30, 23800)
# 0.3333333333333333
