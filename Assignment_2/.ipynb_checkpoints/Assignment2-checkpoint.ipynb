# %% [markdown]
# ## <center> ECSE 415 - Intro to Computer Vision </center>
# ### <center> Assignment 2</center> <center> Saima Haneef - 260744058 </center>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import glob
import math

# %% [markdown]
# ## 1. Image Stitching

# %%
path1 ='./stitchingimages/*.jpg'

# load the image
img = cv2.imread('./stitchingimages/IMG_6257.jpg')
img2 = cv2.imread('./stitchingimages/IMG_6258.jpg')
img3 = cv2.imread('./stitchingimages/IMG_6259.jpg')

# convert to grayscale
left = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
center = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
right = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)

plt.figure(figsize = (20,100))
plt.subplot(131)
plt.imshow(left)
plt.title("Left Image"), plt.xticks([]), plt.yticks([])

plt.subplot(132)
plt.imshow(center)
plt.title("Center Image"), plt.xticks([]), plt.yticks([])

plt.subplot(133)
plt.imshow(right)
plt.title("Right Image"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img_disp = left.copy()
# convert to RGB
img = cv2.cvtColor(left, cv2.COLOR_BGR2RGB)
img_disp = cv2.cvtColor(img_disp, cv2.COLOR_BGR2RGB)

# create a SIFT object
sift = cv2.xfeatures2d.SIFT_create()

# detect SIFT features, with no masks
keypoints = sift.detect(img, None)

# draw the keypoints
cv2.drawKeypoints(img, keypoints, img_disp, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)


# display
plt.figure(figsize=(10,10))
plt.subplot(121), plt.imshow(img)
plt.title("Input Image"), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(img_disp)
plt.title("SIFT Features"), plt.xticks([]), plt.yticks([])
plt.show()

# num of SIFT keypoints
print('Num keypoints: '+ str(len(keypoints)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-f4b82923e6e4> in <module>
#       5
#       6 # create a SIFT object
# ----> 7 sift = cv2.xfeatures2d.SIFT_create()
#       8
#       9 # detect SIFT features, with no masks
#
# AttributeError: module 'cv2.cv2' has no attribute 'xfeatures2d'

# %% [markdown]
# ## 2. Object Detection

# %% [markdown]
# ### 2.1 Training

# %%
def HoGfeatures(img, cell_size, block_size, nbins):

    hog = cv2.HOGDescriptor(_winSize=(img.shape[1] // cell_size[1] * cell_size[1],
                                          img.shape[0] // cell_size[0] * cell_size[0]),
                                _blockSize=(block_size[1] * cell_size[1],
                                            block_size[0] * cell_size[0]),
                                _blockStride=(cell_size[1], cell_size[0]),
                                _cellSize=(cell_size[1], cell_size[0]),
                                _nbins=nbins)


    # Compute HoG features
    feats = hog.compute(img)
    return feats

# %%
path='./train_set/*.png'
feats=[]

x = './train_set/p12.png'
x = cv2.cvtColor(cv2.imread(x),cv2.COLOR_BGR2GRAY)
x = cv2.resize(x,(128,128))

cell_size = (4, 4)  # h x w in pixels
block_size = (2, 2)  # h x w in cells
nbins = 9  # number of orientation bins
feats = HoGfeatures(x, cell_size, block_size, nbins)
# hog = cv2.HOGDescriptor(_winSize=(x.shape[1] // cell_size[1] * cell_size[1],
#                                       x.shape[0] // cell_size[0] * cell_size[0]),
#                             _blockSize=(block_size[1] * cell_size[1],
#                                         block_size[0] * cell_size[0]),
#                             _blockStride=(cell_size[1], cell_size[0]),
#                             _cellSize=(cell_size[1], cell_size[0]),
#                             _nbins=nbins)

# # number of rows and columns in the image
# n_cells = (x.shape[0] // cell_size[0], x.shape[1] // cell_size[1])

# # Compute HoG features
# feats = hog.compute(x)
#feats.append(hog_feats)
print(feats)


for x in glob.glob(path):
    x = cv2.cvtColor(cv2.imread(x),cv2.COLOR_BGR2GRAY)
    x = cv2.resize(x,(128,128))

    # Compute HoG features
    hog_feats = HoGfeatures(x, cell_size, block_size, nbins)
    feats = np.append(feats,hog_feats,axis = 1)

avfeats = np.average(feats,axis=1).reshape(feats.shape[0], 1)

print(avfeats)

# number of rows and columns in the image
n_cells = (x.shape[0] // cell_size[0], x.shape[1] // cell_size[1])

# Compute HoG features
feats_reshaped = avfeats \
               .reshape(n_cells[1] - block_size[1] + 1,
                        n_cells[0] - block_size[0] + 1,
                        block_size[1], block_size[0], nbins) \
               .transpose((1, 0, 3, 2, 4))  # index blocks by rows first


# Preview
plt.figure(figsize = (20,100))
for n in range(9):
    plt.subplot(191+n)
    plt.pcolor(feats_reshaped[:, :, 0,0,n])
    plt.gca().invert_yaxis()
    plt.gca().set_aspect('equal', adjustable='box')
    plt.title("HOG bin " + str(n)+ ", block = 1"), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 2.2 Testing

# %%
# read the image and define the stepSize and window size 
# https://www.w3resource.com/python-exercises/math/python-math-exercise-79.php
# (width,height)
# load the image
image = cv2.imread("test_image.png")
cell_size = (4, 4)  # h x w in pixels
block_size = (2, 2)  # h x w in cells
nbins = 9  # number of orientation bins
count = 0

# # convert to grayscale
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# image = cv2.imread("test_image.png",cv2.COLOR_BGR2GRAY) # your image path
# plt.imshow(image, cmap="gray")
# plt.show()
tmp = image.copy()# for drawing a rectangle
stepSizex = 50
stepSizey = 70
(w_width, w_height) = (250,450) # window size

for y in range(0, image.shape[0]-stepSizey, stepSizex):
   for x in range(0, image.shape[1]-stepSizex, stepSizey):
      window = image[y:y + w_height, x:x+w_width]
      window = cv2.resize(window,(128,128))
      featmap = HoGfeatures(window, cell_size, block_size, nbins)

#       distance = math.sqrt(sum([(a - b) ** 2 for a, b in zip(avfeats, featmap)]))
      distance = np.linalg.norm(avfeats-featmap)
#       print(distance)
        
      if distance<=19 and distance>18:
        if count==4:
            break
        tmp = cv2.rectangle(tmp, (x, y), (x + w_width, y + w_height), (255, 0, 0), 2) # draw rectangle on image
        print(distance, x, y, tmp.shape)
        count = count + 1
#         for i in range(image.shape[1]):
#             print((tmp-image)[200,i])
#         tmp = cv2.putText(tmp,"hello",(x, y), cv2.FONT_HERSHEY_PLAIN, fontScale = 1,color=(255,255,255), thickness =1)
#         plt.figure(figsize =(50,50))       
        plt.imshow(tmp, cmap = "gray")
        plt.show()
#           plt.imshow(np.array(tmp).astype('uint8'), cmap="gray")
# show all windows
# classify content of the window with your classifier and  
# determine if the window includes an object (cell) or not
      # draw window on image
      
plt.show()
